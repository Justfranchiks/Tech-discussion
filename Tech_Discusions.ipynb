# %% [markdown]
# <a href="https://colab.research.google.com/github/Justfranchiks/Tech-discussion/blob/main/Tech_Discusions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def Hello():
  return "Hi"
  Hello()

# %% [markdown]
# ## EDA

# %% [markdown]
# ### This's a markdown heading
# * one
# * two

# %% [markdown]
# ## Modeling Phase

# %% [markdown]
# ## Conclusion
